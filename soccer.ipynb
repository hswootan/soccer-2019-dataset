# %%
import pandas as pd

data_frame = pd.read_csv("Desktop/data.csv")

data_frame.shape
# Out:
# (18207, 89)

# %%
data_frame.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
data_frame.values
# Out:
# array([[0, 158023, 'L. Messi', ..., 14.0, 8.0, '€226.5M'],
#        [1, 20801, 'Cristiano Ronaldo', ..., 14.0, 11.0, '€127.1M'],
#        [2, 190871, 'Neymar Jr', ..., 15.0, 11.0, '€228.1M'],
#        ...,
#        [18204, 241638, 'B. Worman', ..., 6.0, 13.0, '€165K'],
#        [18205, 246268, 'D. Walker-Rice', ..., 8.0, 9.0, '€143K'],
#        [18206, 246269, 'G. Nugent', ..., 12.0, 9.0, '€165K']],
#       dtype=object)

# %%
data_frame.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data_frame["Age"].hist()
# Out:
# <AxesSubplot:>

# %%
data_frame["Marking"].unique()
# Out:
# array([33., 28., 27., 15., 68., 34., 60., 62., 87., 72., 90., 59., 23.,
#        56., 25., 20., 52., 17., 30., 93., 38., 88., 51., 55., 71., 54.,
#        29., 35., 13., 45., 91., 66., 75., 36., 49., 42., 47., 78., 81.,
#        44., 67., 89., 24., 85., 92., 40., 31., 77., 80., 86., 83., 69.,
#        84., 82., 64., 58., 63., 70., 46., 48., 39., 10., 73., 43., 32.,
#        14., 50., 94., 53., 26., 19., 16., 65., 41., 79.,  9., 12., 21.,
#        76., 37., 18., 57., 22., 11., 74., 61.,  7.,  8.,  4.,  3.,  5.,
#         6., nan])

# %%
data_frame["Name"].head()
# Out:
# 0             L. Messi
# 1    Cristiano Ronaldo
# 2            Neymar Jr
# 3               De Gea
# 4         K. De Bruyne
# Name: Name, dtype: object

# %%
data_frame.sort_values("Age", ascending=True).head()
# Out:
#        Unnamed: 0      ID         Name  Age  \
# 18206       18206  246269    G. Nugent   16
# 17743       17743  244752    J. Olstad   16
# 13293       13293  246594  H. Massengo   16
# 16081       16081  241552  J. Italiano   16
# 18166       18166  243621     N. Ayéva   16
#
#                                                 Photo Nationality  \
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
# 17743  https://cdn.sofifa.org/players/4/19/244752.png      Norway
# 13293  https://cdn.sofifa.org/players/4/19/246594.png      France
# 16081  https://cdn.sofifa.org/players/4/19/241552.png   Australia
# 18166  https://cdn.sofifa.org/players/4/19/243621.png      Sweden
#
#                                        Flag  Overall  Potential  \
# 18206   https://cdn.sofifa.org/flags/14.png       46         66
# 17743   https://cdn.sofifa.org/flags/36.png       52         69
# 13293   https://cdn.sofifa.org/flags/18.png       62         75
# ...

# %%
potential_group = data_frame.groupby("Potential")
potential_group.mean()
# Out:
#              Unnamed: 0             ID        Age    Overall      Special  \
# Potential
# 48         18177.000000  145747.000000  38.500000  48.000000  1018.000000
# 50         18034.000000  224703.500000  29.000000  50.000000   880.500000
# 51         18020.000000  212775.500000  27.500000  50.500000  1126.500000
# 52         17903.800000  219816.800000  30.200000  51.300000  1165.600000
# 53         17734.333333  168820.833333  34.166667  52.500000  1096.500000
# 54         17518.285714  205228.142857  31.000000  53.428571  1202.142857
# 55         17332.833333  212508.055556  27.944444  53.888889  1351.444444
# 56         17151.833333  221018.250000  28.083333  54.791667  1169.625000
# 57         16994.319149  206004.000000  27.851064  55.042553  1299.340426
# 58         16902.321839  218329.770115  26.425287  55.091954  1284.034483
# 59         16334.024000  213809.880000  26.992000  56.496000  1382.360000
# ...

# %%
data_frame.iloc[0, :]
# Out:
# Unnamed: 0                                                     0
# ID                                                        158023
# Name                                                    L. Messi
# Age                                                           31
# Photo             https://cdn.sofifa.org/players/4/19/158023.png
#                                        ...
# GKHandling                                                  11.0
# GKKicking                                                   15.0
# GKPositioning                                               14.0
# GKReflexes                                                   8.0
# Release Clause                                           €226.5M
# Name: 0, Length: 89, dtype: object

# %%
data_frame.iloc[0, 2]
# Out:
# 'L. Messi'

# %%
data_frame[pd.isnull(df).any(axis=1)].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11552/1774247109.py in <module>
# ----> 1 data_frame[pd.isnull(df).any(axis=1)].head()
#
# NameError: name 'df' is not defined

# %%
data_frame.loc[0]
# Out:
# Unnamed: 0                                                     0
# ID                                                        158023
# Name                                                    L. Messi
# Age                                                           31
# Photo             https://cdn.sofifa.org/players/4/19/158023.png
#                                        ...
# GKHandling                                                  11.0
# GKKicking                                                   15.0
# GKPositioning                                               14.0
# GKReflexes                                                   8.0
# Release Clause                                           €226.5M
# Name: 0, Length: 89, dtype: object

# %%
data_frame[data_frame["Age"]==30].head()
# Out:
#     Unnamed: 0      ID        Name  Age  \
# 23          23  153079   S. Agüero   30
# 35          35  176676     Marcelo   30
# 38          38  167664  G. Higuaín   30
# 52          52  171877   M. Hamšík   30
# 53          53  168651  I. Rakitić   30
#
#                                              Photo Nationality  \
# 23  https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 35  https://cdn.sofifa.org/players/4/19/176676.png      Brazil
# 38  https://cdn.sofifa.org/players/4/19/167664.png   Argentina
# 52  https://cdn.sofifa.org/players/4/19/171877.png    Slovakia
# 53  https://cdn.sofifa.org/players/4/19/168651.png     Croatia
#
#                                    Flag  Overall  Potential             Club  \
# 23  https://cdn.sofifa.org/flags/52.png       89         89  Manchester City
# 35  https://cdn.sofifa.org/flags/54.png       88         88      Real Madrid
# 38  https://cdn.sofifa.org/flags/52.png       88         88            Milan
# ...

# %%
df1 = pd.DataFrame(data_frame, columns=['Name', 'Wage', 'Value'])

def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

wage = df1['Wage'].replace('[\€]', '', regex=True).apply(value_to_float)
value = df1['Value'].replace('[\€]', '', regex=True).apply(value_to_float)

df1['Wage'] = wage
df1['Value'] = value

df1['difference'] = df1['Value'] - df1['Wage']
df1.sort_values('difference', ascending=False)
# Out:
#                Name      Wage        Value   difference
# 2         Neymar Jr  290000.0  118500000.0  118210000.0
# 0          L. Messi  565000.0  110500000.0  109935000.0
# 4      K. De Bruyne  355000.0  102000000.0  101645000.0
# 5         E. Hazard  340000.0   93000000.0   92660000.0
# 15        P. Dybala  205000.0   89000000.0   88795000.0
# ...             ...       ...          ...          ...
# 17752   S. Phillips    1000.0          0.0      -1000.0
# 12192  H. Sulaimani    3000.0          0.0      -3000.0
# 3550    S. Nakamura    4000.0          0.0      -4000.0
# 4228       B. Nivet    5000.0          0.0      -5000.0
# 864          Hilton   18000.0          0.0     -18000.0
#
# [18207 rows x 4 columns]

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x='Wage', y='Value', data=df1)

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage,Value)", "(@Wage, @Value)"),
    ("Name", "@Name")])

silence(EMPTY_LAYOUT, True)
silence(MISSING_RENDERERS, True)

p = figure(title="Soccer 2019 data", x_axis_label='Wage', y_axis_label='Value', plot_width=700, plot_height=700, tools=[TOOLTIPS])
show(p)

p.circle('Wage','Value', size=10, source=df1)

show(p)
